# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({
    'Name': ['Elias', 'Efrain'],
    'Age': [23, 45],
    'Height': [1.75, 1.80],
    'Weight': [70, 80],
})

# %%
df.loc[0, 'Age']
# Out:
# 23
